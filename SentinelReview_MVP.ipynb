# %% [markdown]
# - Goal: multi-agent PR review
# - Input: git diff
# - Output: structured review
# - Agents involved

# %%
from typing import List, Dict, Any
from dataclasses import dataclass
# Out:
# Running cells with '.venv (Python 3.10.19)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/kiranrawat/Desktop/Personal_Projects/SentinelReview/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
